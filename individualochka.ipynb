# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
netflix = pd.read_csv('netflix.csv')
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# Список фильмов которые вышли между 2020 и 2021 годами

# %%
l = netflix[netflix['release_year'].between(2020, 2021)]
l
# Out:
#      show_id     type                                      title  \
# 0         s1    Movie                       Dick Johnson Is Dead
# 1         s2  TV Show                              Blood & Water
# 2         s3  TV Show                                  Ganglands
# 3         s4  TV Show                      Jailbirds New Orleans
# 4         s5  TV Show                               Kota Factory
# ...      ...      ...                                        ...
# 7594   s7595    Movie         Norm of the North: Family Vacation
# 8099   s8100    Movie                                Straight Up
# 8125   s8126  TV Show                                Super Wings
# 8132   s8133  TV Show  Surviving R. Kelly Part II: The Reckoning
# 8437   s8438  TV Show                     The Netflix Afterparty
#
#              director                                               cast  \
# 0     Kirsten Johnson                                                NaN
# ...

# %% [markdown]
# 10 самых длинных фильмов от Netflix

# %%
netflix.sort_values(by=['duration'], ascending=False).head(10)
# Out:
#      show_id   type                                  title  \
# 1329   s1330  Movie  The Misadventures of Hedi and Cokeman
# 6278   s6279  Movie                               Being AP
# 952     s953  Movie                   The Whole Nine Yards
# 6141   s6142  Movie                       American Hangman
# 929     s930  Movie                Dead Again in Tombstone
# 5146   s5147  Movie                             The Worthy
# 910     s911  Movie                                Monster
# 2780   s2781  Movie                                 Curtiz
# 894     s895  Movie                 Dance of the Forty One
# 7424   s7425  Movie                            May We Chat
#
#                     director  \
# 1329            Julien Royal
# 6278           Anthony Wonke
# 952            Jonathan Lynn
# 6141       Wilson Coneybeare
# 929               Roel Reiné
# 5146          Ali F. Mostafa
# 910          Anthony Mandler
# 2780  Tamas Yvan Topolanszky
# 894             David Pablos
# ...

# %% [markdown]
# #### Отобразили первые 10 полей своего датасета

# %%
netflix.loc[1:10]
# Out:
#    show_id     type                                title  \
# 1       s2  TV Show                        Blood & Water
# 2       s3  TV Show                            Ganglands
# 3       s4  TV Show                Jailbirds New Orleans
# 4       s5  TV Show                         Kota Factory
# 5       s6  TV Show                        Midnight Mass
# 6       s7    Movie     My Little Pony: A New Generation
# 7       s8    Movie                              Sankofa
# 8       s9  TV Show        The Great British Baking Show
# 9      s10    Movie                         The Starling
# 10     s11  TV Show  Vendetta: Truth, Lies and The Mafia
#
#                          director  \
# 1                             NaN
# 2                 Julien Leclercq
# 3                             NaN
# 4                             NaN
# 5                   Mike Flanagan
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 8                 Andy Devonshire
# ...

# %% [markdown]
# ## Рейтинги, которые принадлежат фильмам и сериалам.

# %% [markdown]
# #### Cправка рейтингов
# Рейтинг TV-Y (Young): Телепрограмма специально предназначенная для просмотра детьми любого возраста. <p>
# Рейтинг TV-Y7 (Young above 7): Телепрограмма специально предназначенная для просмотра детьми старше семи лет. <p>
# Рейтинг TV-G (General): Аналог кинорейтинга G.<p>
# Рейтинг TV-PG (Parental guidance): Аналог кинорейтинга PG.<p>
# Рейтинг TV-14 (14 and above): Аналог кинорейтинга PG-13.<p>
# Рейтинг TV-MA (Mature audience): Аналог кинорейтинга R.<p>
# Рейтинг G (General): Фильм можно показывать любым детям без ограничений.
# <p>Рейтинг PG (Parental guidance): Фильм содержит моменты, которые могут быть неподобающими для детей (например, в кадре промелькнет кто-нибудь голый). Родителям рекомендуется ознакомиться, какие именно, и стоит ли их ребенку смотреть такой фильм.
# <p>Рейтинг PG-13 (Parental guidance for children under 13): Фильм содержит моменты, которые могут быть неподобающими для детей до 13 лет (например, кто-нибудь кого-нибудь пошлет матом или хорошо подрался). Рейтинг был выделен из PG в 1984 г.
# <p>Рейтинг R (Restricted): Дети до 17 лет допускаются только при сопровождении взрослого. Обычный фак-перефак, или боевик со множеством смертей, но без особого их смакования, или сексуальные сцены, но без излишнего графизма.
# <p>Рейтинг NC-17 (No children under 17): Дети до 17 лет к просмотру не допускаются. До 1990 г. рейтинг обозначался как X и был переименован из-за того, что икс к тому времени стойко ассоциировался с порнографией и губил прокат недетских, но вполне пристойных фильмов.
#
# В связи с большим обьемом данных, рейтинги популярность которых ниже NP не рассматриваются

# %%
netflix.groupby('rating').size().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# #### Все фильмы с жанрами 'Драма'

# %%
netflix[netflix.listed_in == 'Dramas'].head()
# Out:
#     show_id   type                title             director  \
# 112    s113  Movie                Worth       Sara Colangelo
# 129    s130  Movie   An Unfinished Life      Lasse Hallström
# 142    s143  Movie      Freedom Writers  Richard LaGravenese
# 162    s163  Movie             Marshall      Reginald Hudlin
# 329    s330  Movie  Catch Me If You Can     Steven Spielberg
#
#                                                   cast  \
# 112  Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129  Robert Redford, Jennifer Lopez, Morgan Freeman...
# 142  Hilary Swank, Patrick Dempsey, Scott Glenn, Im...
# 162  Chadwick Boseman, Josh Gad, Kate Hudson, Sterl...
# 329  Leonardo DiCaprio, Tom Hanks, Christopher Walk...
#
#                              country         date_added  release_year rating  \
# 112                              NaN  September 3, 2021          2021  PG-13
# 129           Germany, United States  September 1, 2021          2005  PG-13
# ...
